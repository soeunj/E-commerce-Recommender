# %%
#import basic Libraries
import pandas as pd
import numpy as np
from tqdm import tqdm

#Importing Sklearn
from sklearn.preprocessing import StandardScaler, OneHotEncoder

#Import Market Basket Models
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# # Cleaning Dataset

# %%
opt = pd.read_csv('../data/hidem_ord.csv')
opt = opt.drop('Unnamed: 0', axis=1)

# %%
opt
# Out:
#        order_id  product_id  add_to_cart_order  reordered  \
# 0             1       11109                  2          1
# 1             1       22035                  8          1
# 2            36       19660                  2          1
# 3            36       48679                  7          1
# 4            36       46979                  8          1
# 5            38       21616                  4          1
# 6            96       40706                  3          1
# 7            98       43654                  3          1
# 8            98       35951                  8          1
# 9            98        9896                 10          1
# 10           98       27509                 11          1
# 11           98       27966                 13          1
# 12           98       47601                 14          1
# 13           98       40396                 15          1
# 14           98       40986                 17          1
# 15           98       46313                 19          1
# 16           98         329                 20          1
# 17           98       30776                 21          1
# 18           98       36695                 22          1
# 19           98       27344                 25          1
# 20           98       24964                 29          1
# 21           98       18117                 30          1
# 22           98       46413                 31          1
# 23           98       34126                 32          1
# 24           98       22935                 34          1
# 25           98       46720                 35          1
# 26           98       18441                 38          1
# 27           98       45007                 39          1
# 28           98        3880                 43          1
# 29          112       21174                  2          1
# ...         ...         ...                ...        ...
# 22276    206033       44714                  5          1
# 22277    206033       10957                  6          1
# 22278    206033       19134                  8          1
# 22279    206033       27117                  9          1
# 22280    206033        2966                 10          1
# 22281    206082       12957                  2          1
# 22282    206138        8381                  2          1
# 22283    206150       46720                  1          1
# 22284    206150       15872                  2          1
# 22285    206150       16759                  5          1
# 22286    206150       23339                  6          1
# 22287    206176       26856                  1          1
# 22288    206176       44142                  5          1
# 22289    206176       40660                  8          1
# 22290    206205        5077                  7          1
# 22291    206205       34969                 12          1
# 22292    206208       23622                  3          1
# 22293    206208       39619                 12          1
# 22294    206208       18441                 15          1
# 22295    206210       36612                  1          1
# 22296    206210       35865                  4          1
# 22297    206210       49114                  8          1
# 22298    206210       38618                  9          1
# 22299    206210       24852                 10          1
# 22300    206210       31553                 11          1
# 22301    206210       35078                 12          1
# 22302    206294       44632                  1          1
# 22303    206294       27464                  2          1
# 22304    206296       23695                  1          1
# 22305    206296       26209                  4          1
#
#                                             product_name  aisle_id  \
# 0          Organic 4% Milk Fat Whole Milk Cottage Cheese       108
# 1                            Organic Whole String Cheese        21
# 2                                           Spring Water       115
# 3                      Organic Garnet Sweet Potato (Yam)        83
# 4                                              Asparagus        83
# 5                                   Organic Baby Arugula       123
# 6                                 Organic Grape Tomatoes       123
# 7           Whole Milk Greek Blended Vanilla Bean Yogurt       120
# 8                        Organic Unsweetened Almond Milk        91
# 9                         Uncured Applewood Smoked Bacon       106
# 10     Organic Seasoned Yukon Select Potatoes Hashed ...       129
# 11                                   Organic Raspberries       123
# 12                              Unsalted Cultured Butter        36
# 13                                             Guacamole        67
# 14                                 Raspberry Sorbet Pops        37
# 15                              Baby Swiss Slices Cheese        21
# 16                          Organic Whole Grassmilk Milk        84
# 17                        Organic Raw Kombucha Gingerade        31
# 18                            Organic Hothouse Cucumbers        83
# 19                                  Uncured Genoa Salami        96
# 20                                        Organic Garlic        83
# 21             100% Organic Unbleached All-Purpose Flour        17
# 22                      Lavender Scent Laundry Detergent        75
# 23                         Organic Italian Parsley Bunch        16
# 24                                  Organic Yellow Onion        83
# 25                      Organic Free Range Chicken Broth        69
# 26                                       Organic Ketchup        72
# 27                                      Organic Zucchini        83
# 28                                  Corn Maize Tortillas       128
# 29                                     I Heart Baby Kale       123
# ...                                                  ...       ...
# 22276                              Mint & Dark Chocolate        45
# 22277                                   Fridge Pack Cola        77
# 22278                       Crunchy Variety Pack Granola        48
# 22279                                 Refresh Herbal Tea        94
# 22280                                 Pure Coconut Water        98
# 22281                    Gluten Free Matzo Style Squares        33
# 22282                       34% Cacao Milk Chocolate Bar        45
# 22283                   Organic Free Range Chicken Broth        69
# 22284                                      Celery Hearts        83
# 22285                               Organic Carrot Bunch        83
# 22286                              Sweet Corn On The Cob        83
# 22287                   Organic Ezekiel 4:9 Sesame Bread       112
# 22288                                          Red Onion        83
# 22289                               Almond Butter Smooth        88
# 22290                             100% Whole Wheat Bread       112
# 22291                                    Red Vine Tomato        83
# 22292                           Organic Hot House Tomato        83
# 22293                   Organic Tomato Basil Pasta Sauce         9
# 22294                                    Organic Ketchup        72
# 22295                        Original Wheat Berry Flakes       121
# 22296                               Cream of Tomato Soup        69
# 22297                    Organic Soups Alphabet Fat Free        69
# 22298                      Organic Chunky Vegetable Soup        69
# 22299                                             Banana        24
# 22300                                  Fresh Ginger Root        83
# 22301                     Seriously Sharp Cheddar Cheese        21
# 22302                         Sparkling Water Grapefruit       115
# 22303  Direct Trade House Blend Medium Roast Ground C...        26
# 22304                           California Veggie Burger        42
# 22305                                              Limes        24
#
#        department_id       department                          aisle  hi_dem  \
# 0                 16       dairy eggs           other creams cheeses    True
# 1                 16       dairy eggs                packaged cheese    True
# 2                  7        beverages  water seltzer sparkling water    True
# 3                  4          produce               fresh vegetables    True
# 4                  4          produce               fresh vegetables    True
# 5                  4          produce     packaged vegetables fruits    True
# 6                  4          produce     packaged vegetables fruits    True
# 7                 16       dairy eggs                         yogurt    True
# 8                 16       dairy eggs                soy lactosefree    True
# 9                 12     meat seafood         hot dogs bacon sausage    True
# 10                 1           frozen        frozen appetizers sides    True
# 11                 4          produce     packaged vegetables fruits    True
# 12                16       dairy eggs                         butter    True
# 13                20             deli           fresh dips tapenades    True
# 14                 1           frozen                  ice cream ice    True
# 15                16       dairy eggs                packaged cheese    True
# 16                16       dairy eggs                           milk    True
# 17                 7        beverages                   refrigerated    True
# 18                 4          produce               fresh vegetables    True
# 19                20             deli                     lunch meat    True
# 20                 4          produce               fresh vegetables    True
# 21                13           pantry             baking ingredients    True
# 22                17        household                        laundry    True
# 23                 4          produce                    fresh herbs    True
# 24                 4          produce               fresh vegetables    True
# 25                15     canned goods            soup broth bouillon    True
# 26                13           pantry                     condiments    True
# 27                 4          produce               fresh vegetables    True
# 28                 3           bakery           tortillas flat bread    True
# 29                 4          produce     packaged vegetables fruits    True
# ...              ...              ...                            ...     ...
# 22276             19           snacks                candy chocolate    True
# 22277              7        beverages                    soft drinks    True
# 22278             14        breakfast        breakfast bars pastries    True
# 22279              7        beverages                            tea    True
# 22280              7        beverages                  juice nectars    True
# 22281              6    international                   kosher foods    True
# 22282             19           snacks                candy chocolate    True
# 22283             15     canned goods            soup broth bouillon    True
# 22284              4          produce               fresh vegetables    True
# 22285              4          produce               fresh vegetables    True
# 22286              4          produce               fresh vegetables    True
# 22287              3           bakery                          bread    True
# 22288              4          produce               fresh vegetables    True
# 22289             13           pantry                        spreads    True
# 22290              3           bakery                          bread    True
# 22291              4          produce               fresh vegetables    True
# 22292              4          produce               fresh vegetables    True
# 22293              9  dry goods pasta                    pasta sauce    True
# 22294             13           pantry                     condiments    True
# 22295             14        breakfast                         cereal    True
# 22296             15     canned goods            soup broth bouillon    True
# 22297             15     canned goods            soup broth bouillon    True
# 22298             15     canned goods            soup broth bouillon    True
# 22299              4          produce                   fresh fruits    True
# 22300              4          produce               fresh vegetables    True
# 22301             16       dairy eggs                packaged cheese    True
# 22302              7        beverages  water seltzer sparkling water    True
# 22303              7        beverages                         coffee    True
# 22304              1           frozen        frozen vegan vegetarian    True
# 22305              4          produce                   fresh fruits    True
#
#        user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0       112108    train             4          4                 10
# 1       112108    train             4          4                 10
# 2        79431    train            23          6                 18
# 3        79431    train            23          6                 18
# 4        79431    train            23          6                 18
# 5        42756    train             6          6                 16
# 6        17227    train             7          6                 20
# 7        56463    train            41          3                  8
# 8        56463    train            41          3                  8
# 9        56463    train            41          3                  8
# 10       56463    train            41          3                  8
# 11       56463    train            41          3                  8
# 12       56463    train            41          3                  8
# 13       56463    train            41          3                  8
# 14       56463    train            41          3                  8
# 15       56463    train            41          3                  8
# 16       56463    train            41          3                  8
# 17       56463    train            41          3                  8
# 18       56463    train            41          3                  8
# 19       56463    train            41          3                  8
# 20       56463    train            41          3                  8
# 21       56463    train            41          3                  8
# 22       56463    train            41          3                  8
# 23       56463    train            41          3                  8
# 24       56463    train            41          3                  8
# 25       56463    train            41          3                  8
# 26       56463    train            41          3                  8
# 27       56463    train            41          3                  8
# 28       56463    train            41          3                  8
# 29      125030    train             5          5                 14
# ...        ...      ...           ...        ...                ...
# 22276   133614    train            15          1                  9
# 22277   133614    train            15          1                  9
# 22278   133614    train            15          1                  9
# 22279   133614    train            15          1                  9
# 22280   133614    train            15          1                  9
# 22281   188554    train            13          2                 19
# 22282    76391    train            23          4                  0
# 22283   195446    train            23          6                 11
# 22284   195446    train            23          6                 11
# 22285   195446    train            23          6                 11
# 22286   195446    train            23          6                 11
# 22287    27274    train             4          1                 18
# 22288    27274    train             4          1                 18
# 22289    27274    train             4          1                 18
# 22290   149920    train             7          2                 12
# 22291   149920    train             7          2                 12
# 22292     9640    train            16          6                 11
# 22293     9640    train            16          6                 11
# 22294     9640    train            16          6                 11
# 22295   136988    train            14          4                  6
# 22296   136988    train            14          4                  6
# 22297   136988    train            14          4                  6
# 22298   136988    train            14          4                  6
# 22299   136988    train            14          4                  6
# 22300   136988    train            14          4                  6
# 22301   136988    train            14          4                  6
# 22302   131809    train             5          3                 22
# 22303   131809    train             5          3                 22
# 22304    67972    train            34          2                  7
# 22305    67972    train            34          2                  7
#
#        days_since_prior_order
# 0                         9.0
# 1                         9.0
# 2                        30.0
# 3                        30.0
# 4                        30.0
# 5                        24.0
# 6                        30.0
# 7                        14.0
# 8                        14.0
# 9                        14.0
# 10                       14.0
# 11                       14.0
# 12                       14.0
# 13                       14.0
# 14                       14.0
# 15                       14.0
# 16                       14.0
# 17                       14.0
# 18                       14.0
# 19                       14.0
# 20                       14.0
# 21                       14.0
# 22                       14.0
# 23                       14.0
# 24                       14.0
# 25                       14.0
# 26                       14.0
# 27                       14.0
# 28                       14.0
# 29                       26.0
# ...                       ...
# 22276                    30.0
# 22277                    30.0
# 22278                    30.0
# 22279                    30.0
# 22280                    30.0
# 22281                    30.0
# 22282                     6.0
# 22283                     9.0
# 22284                     9.0
# 22285                     9.0
# 22286                     9.0
# 22287                    30.0
# 22288                    30.0
# 22289                    30.0
# 22290                    21.0
# 22291                    21.0
# 22292                    12.0
# 22293                    12.0
# 22294                    12.0
# 22295                    30.0
# 22296                    30.0
# 22297                    30.0
# 22298                    30.0
# 22299                    30.0
# 22300                    30.0
# 22301                    30.0
# 22302                    15.0
# 22303                    15.0
# 22304                     7.0
# 22305                     7.0
#
# [22306 rows x 16 columns]

# %%
#adding food group for non food departments as 'other'
non_food_dep = ['household','pets','personal care', 'alcohol','beverages', 'babies', 'missing']
#adding food group for departments which are not ambiguous to proper food group
food_dep = {'bakery':'sugar, snacks, and bakeries','meat seafood':'proteins', 'canned goods':'processed foods'}

for (i, row) in opt.iterrows():
    if row['department'] in non_food_dep:
        opt.at[i,'foodgroup'] = 'others'
    elif row['department'] in food_dep:
        opt.at[i,'foodgroup'] = food_dep[row['department']]

# %%
#converting the foodgroup to string to preserve order.
opt['foodgroup'] = opt['foodgroup'].astype(str)

# %% [markdown]
# This project aims to implement recommender specifically for diet. Therefore, information related to diet could be different with other diet research and not percise.
#
# This project uses 8 food groups, such as #carbohydrates #proteins #vegetables and fruits #diary products and alternatives #fat #processed foods #sugar, sweets, and bakeries #others.

# %%
#adding food group for aisle
food_aisle_carbohydrates = ['bulk grains rice dried goods', 'cereal', 'doughs gelatins bake mixes', 'dry pasta', 'fresh pasta', 'frozen breads doughs', 'grains rice dried goods', 'granola','hot cereal pancake mixes']
food_aisle_protein = ['eggs','frozen meat seafood', 'lunch meat','tofu meat alternatives']
food_aisle_vegetables_and_fruits = ['bulk dried fruits vegetables', 'fresh fruits', 'fresh herbs', 'fresh vegetables', 'frozen juice', 'packaged vegetables fruits', 'pickled goods olives', 'packaged produce']
food_aisle_diary_products_and_alternatives = ['cream', 'other creams cheeses', 'packaged cheese','soy lactosefree', 'specialty cheeses', 'yogurt', 'milk']
food_aisle_fat = ['butter', 'oils vinegars', 'nuts seeds dried fruit']
food_aisle_processed_foods = ['frozen meals', 'frozen pizza', 'instant foods', 'prepared meals', 'chips pretzels', 'crackers', 'energy granola bars', 'fruit vegetable snacks', 'breakfast bars pastries', 'frozen appetizers sides', 'prepared soups salads', 'frozen produce', 'frozen vegan vegetarian']
food_aisle_sugar_sweets_and_bakeries = ['frozen dessert','honeys syrups nectars', 'ice cream ice', 'refrigerated pudding desserts', 'candy chocolate', 'cookies cakes', 'ice cream toppings', 'mint gum', 'popcorn jerky', 'trail mix snack mix', 'baking ingredients', 'frozen breakfast']

for (i, row) in opt.iterrows():
    if row['aisle'] in food_aisle_carbohydrates:
        opt.at[i,'foodgroup'] = 'carbohydrates'
    elif row['aisle'] in food_aisle_protein:
        opt.at[i,'foodgroup'] = 'proteins'
    elif row['aisle'] in food_aisle_vegetables_and_fruits:
        opt.at[i,'foodgroup'] = 'vegetables and fruits'
    elif row['aisle'] in food_aisle_diary_products_and_alternatives:
        opt.at[i,'foodgroup'] = 'diary products and alternatives'
    elif row['aisle'] in food_aisle_fat:
        opt.at[i,'foodgroup'] = 'fat'
    elif row['aisle'] in food_aisle_processed_foods:
        opt.at[i,'foodgroup'] = 'processed foods'
    elif row['aisle'] in food_aisle_sugar_sweets_and_bakeries:
        opt.at[i,'foodgroup'] = 'sugar sweets and bakeries'
    else:
        opt.at[i,'foodgroup'] = 'others'

# %%
unique_pair = opt[opt.foodgroup == 'nan'].groupby(['aisle','department']).size()

# %%
unique_pair
# Out:
# Series([], dtype: int64)

# %%
opt[opt.foodgroup == 'nan']
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered, product_name, aisle_id, department_id, department, aisle, hi_dem, user_id, eval_set, order_number, order_dow, order_hour_of_day, days_since_prior_order, foodgroup]
# Index: []

# %%
save_file = opt.to_csv('../data/merged_data_for_diet.csv')

# %%
# Out:
#        order_id  product_id  add_to_cart_order  reordered  \
# 0             1       11109                  2          1
# 1             1       22035                  8          1
# 2            36       19660                  2          1
# 3            36       48679                  7          1
# 4            36       46979                  8          1
# 5            38       21616                  4          1
# 6            96       40706                  3          1
# 7            98       43654                  3          1
# 8            98       35951                  8          1
# 9            98        9896                 10          1
# 10           98       27509                 11          1
# 11           98       27966                 13          1
# 12           98       47601                 14          1
# 13           98       40396                 15          1
# 14           98       40986                 17          1
# 15           98       46313                 19          1
# 16           98         329                 20          1
# 17           98       30776                 21          1
# 18           98       36695                 22          1
# 19           98       27344                 25          1
# 20           98       24964                 29          1
# 21           98       18117                 30          1
# 22           98       46413                 31          1
# 23           98       34126                 32          1
# 24           98       22935                 34          1
# 25           98       46720                 35          1
# 26           98       18441                 38          1
# 27           98       45007                 39          1
# 28           98        3880                 43          1
# 29          112       21174                  2          1
# ...         ...         ...                ...        ...
# 22276    206033       44714                  5          1
# 22277    206033       10957                  6          1
# 22278    206033       19134                  8          1
# 22279    206033       27117                  9          1
# 22280    206033        2966                 10          1
# 22281    206082       12957                  2          1
# 22282    206138        8381                  2          1
# 22283    206150       46720                  1          1
# 22284    206150       15872                  2          1
# 22285    206150       16759                  5          1
# 22286    206150       23339                  6          1
# 22287    206176       26856                  1          1
# 22288    206176       44142                  5          1
# 22289    206176       40660                  8          1
# 22290    206205        5077                  7          1
# 22291    206205       34969                 12          1
# 22292    206208       23622                  3          1
# 22293    206208       39619                 12          1
# 22294    206208       18441                 15          1
# 22295    206210       36612                  1          1
# 22296    206210       35865                  4          1
# 22297    206210       49114                  8          1
# 22298    206210       38618                  9          1
# 22299    206210       24852                 10          1
# 22300    206210       31553                 11          1
# 22301    206210       35078                 12          1
# 22302    206294       44632                  1          1
# 22303    206294       27464                  2          1
# 22304    206296       23695                  1          1
# 22305    206296       26209                  4          1
#
#                                             product_name  aisle_id  \
# 0          Organic 4% Milk Fat Whole Milk Cottage Cheese       108
# 1                            Organic Whole String Cheese        21
# 2                                           Spring Water       115
# 3                      Organic Garnet Sweet Potato (Yam)        83
# 4                                              Asparagus        83
# 5                                   Organic Baby Arugula       123
# 6                                 Organic Grape Tomatoes       123
# 7           Whole Milk Greek Blended Vanilla Bean Yogurt       120
# 8                        Organic Unsweetened Almond Milk        91
# 9                         Uncured Applewood Smoked Bacon       106
# 10     Organic Seasoned Yukon Select Potatoes Hashed ...       129
# 11                                   Organic Raspberries       123
# 12                              Unsalted Cultured Butter        36
# 13                                             Guacamole        67
# 14                                 Raspberry Sorbet Pops        37
# 15                              Baby Swiss Slices Cheese        21
# 16                          Organic Whole Grassmilk Milk        84
# 17                        Organic Raw Kombucha Gingerade        31
# 18                            Organic Hothouse Cucumbers        83
# 19                                  Uncured Genoa Salami        96
# 20                                        Organic Garlic        83
# 21             100% Organic Unbleached All-Purpose Flour        17
# 22                      Lavender Scent Laundry Detergent        75
# 23                         Organic Italian Parsley Bunch        16
# 24                                  Organic Yellow Onion        83
# 25                      Organic Free Range Chicken Broth        69
# 26                                       Organic Ketchup        72
# 27                                      Organic Zucchini        83
# 28                                  Corn Maize Tortillas       128
# 29                                     I Heart Baby Kale       123
# ...                                                  ...       ...
# 22276                              Mint & Dark Chocolate        45
# 22277                                   Fridge Pack Cola        77
# 22278                       Crunchy Variety Pack Granola        48
# 22279                                 Refresh Herbal Tea        94
# 22280                                 Pure Coconut Water        98
# 22281                    Gluten Free Matzo Style Squares        33
# 22282                       34% Cacao Milk Chocolate Bar        45
# 22283                   Organic Free Range Chicken Broth        69
# 22284                                      Celery Hearts        83
# 22285                               Organic Carrot Bunch        83
# 22286                              Sweet Corn On The Cob        83
# 22287                   Organic Ezekiel 4:9 Sesame Bread       112
# 22288                                          Red Onion        83
# 22289                               Almond Butter Smooth        88
# 22290                             100% Whole Wheat Bread       112
# 22291                                    Red Vine Tomato        83
# 22292                           Organic Hot House Tomato        83
# 22293                   Organic Tomato Basil Pasta Sauce         9
# 22294                                    Organic Ketchup        72
# 22295                        Original Wheat Berry Flakes       121
# 22296                               Cream of Tomato Soup        69
# 22297                    Organic Soups Alphabet Fat Free        69
# 22298                      Organic Chunky Vegetable Soup        69
# 22299                                             Banana        24
# 22300                                  Fresh Ginger Root        83
# 22301                     Seriously Sharp Cheddar Cheese        21
# 22302                         Sparkling Water Grapefruit       115
# 22303  Direct Trade House Blend Medium Roast Ground C...        26
# 22304                           California Veggie Burger        42
# 22305                                              Limes        24
#
#        department_id       department                          aisle  hi_dem  \
# 0                 16       dairy eggs           other creams cheeses    True
# 1                 16       dairy eggs                packaged cheese    True
# 2                  7        beverages  water seltzer sparkling water    True
# 3                  4          produce               fresh vegetables    True
# 4                  4          produce               fresh vegetables    True
# 5                  4          produce     packaged vegetables fruits    True
# 6                  4          produce     packaged vegetables fruits    True
# 7                 16       dairy eggs                         yogurt    True
# 8                 16       dairy eggs                soy lactosefree    True
# 9                 12     meat seafood         hot dogs bacon sausage    True
# 10                 1           frozen        frozen appetizers sides    True
# 11                 4          produce     packaged vegetables fruits    True
# 12                16       dairy eggs                         butter    True
# 13                20             deli           fresh dips tapenades    True
# 14                 1           frozen                  ice cream ice    True
# 15                16       dairy eggs                packaged cheese    True
# 16                16       dairy eggs                           milk    True
# 17                 7        beverages                   refrigerated    True
# 18                 4          produce               fresh vegetables    True
# 19                20             deli                     lunch meat    True
# 20                 4          produce               fresh vegetables    True
# 21                13           pantry             baking ingredients    True
# 22                17        household                        laundry    True
# 23                 4          produce                    fresh herbs    True
# 24                 4          produce               fresh vegetables    True
# 25                15     canned goods            soup broth bouillon    True
# 26                13           pantry                     condiments    True
# 27                 4          produce               fresh vegetables    True
# 28                 3           bakery           tortillas flat bread    True
# 29                 4          produce     packaged vegetables fruits    True
# ...              ...              ...                            ...     ...
# 22276             19           snacks                candy chocolate    True
# 22277              7        beverages                    soft drinks    True
# 22278             14        breakfast        breakfast bars pastries    True
# 22279              7        beverages                            tea    True
# 22280              7        beverages                  juice nectars    True
# 22281              6    international                   kosher foods    True
# 22282             19           snacks                candy chocolate    True
# 22283             15     canned goods            soup broth bouillon    True
# 22284              4          produce               fresh vegetables    True
# 22285              4          produce               fresh vegetables    True
# 22286              4          produce               fresh vegetables    True
# 22287              3           bakery                          bread    True
# 22288              4          produce               fresh vegetables    True
# 22289             13           pantry                        spreads    True
# 22290              3           bakery                          bread    True
# 22291              4          produce               fresh vegetables    True
# 22292              4          produce               fresh vegetables    True
# 22293              9  dry goods pasta                    pasta sauce    True
# 22294             13           pantry                     condiments    True
# 22295             14        breakfast                         cereal    True
# 22296             15     canned goods            soup broth bouillon    True
# 22297             15     canned goods            soup broth bouillon    True
# 22298             15     canned goods            soup broth bouillon    True
# 22299              4          produce                   fresh fruits    True
# 22300              4          produce               fresh vegetables    True
# 22301             16       dairy eggs                packaged cheese    True
# 22302              7        beverages  water seltzer sparkling water    True
# 22303              7        beverages                         coffee    True
# 22304              1           frozen        frozen vegan vegetarian    True
# 22305              4          produce                   fresh fruits    True
#
#        user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0       112108    train             4          4                 10
# 1       112108    train             4          4                 10
# 2        79431    train            23          6                 18
# 3        79431    train            23          6                 18
# 4        79431    train            23          6                 18
# 5        42756    train             6          6                 16
# 6        17227    train             7          6                 20
# 7        56463    train            41          3                  8
# 8        56463    train            41          3                  8
# 9        56463    train            41          3                  8
# 10       56463    train            41          3                  8
# 11       56463    train            41          3                  8
# 12       56463    train            41          3                  8
# 13       56463    train            41          3                  8
# 14       56463    train            41          3                  8
# 15       56463    train            41          3                  8
# 16       56463    train            41          3                  8
# 17       56463    train            41          3                  8
# 18       56463    train            41          3                  8
# 19       56463    train            41          3                  8
# 20       56463    train            41          3                  8
# 21       56463    train            41          3                  8
# 22       56463    train            41          3                  8
# 23       56463    train            41          3                  8
# 24       56463    train            41          3                  8
# 25       56463    train            41          3                  8
# 26       56463    train            41          3                  8
# 27       56463    train            41          3                  8
# 28       56463    train            41          3                  8
# 29      125030    train             5          5                 14
# ...        ...      ...           ...        ...                ...
# 22276   133614    train            15          1                  9
# 22277   133614    train            15          1                  9
# 22278   133614    train            15          1                  9
# 22279   133614    train            15          1                  9
# 22280   133614    train            15          1                  9
# 22281   188554    train            13          2                 19
# 22282    76391    train            23          4                  0
# 22283   195446    train            23          6                 11
# 22284   195446    train            23          6                 11
# 22285   195446    train            23          6                 11
# 22286   195446    train            23          6                 11
# 22287    27274    train             4          1                 18
# 22288    27274    train             4          1                 18
# 22289    27274    train             4          1                 18
# 22290   149920    train             7          2                 12
# 22291   149920    train             7          2                 12
# 22292     9640    train            16          6                 11
# 22293     9640    train            16          6                 11
# 22294     9640    train            16          6                 11
# 22295   136988    train            14          4                  6
# 22296   136988    train            14          4                  6
# 22297   136988    train            14          4                  6
# 22298   136988    train            14          4                  6
# 22299   136988    train            14          4                  6
# 22300   136988    train            14          4                  6
# 22301   136988    train            14          4                  6
# 22302   131809    train             5          3                 22
# 22303   131809    train             5          3                 22
# 22304    67972    train            34          2                  7
# 22305    67972    train            34          2                  7
#
#        days_since_prior_order                        foodgroup
# 0                         9.0  diary products and alternatives
# 1                         9.0  diary products and alternatives
# 2                        30.0                           others
# 3                        30.0            vegetables and fruits
# 4                        30.0            vegetables and fruits
# 5                        24.0            vegetables and fruits
# 6                        30.0            vegetables and fruits
# 7                        14.0  diary products and alternatives
# 8                        14.0  diary products and alternatives
# 9                        14.0                           others
# 10                       14.0                  processed foods
# 11                       14.0            vegetables and fruits
# 12                       14.0                              fat
# 13                       14.0                           others
# 14                       14.0        sugar sweets and bakeries
# 15                       14.0  diary products and alternatives
# 16                       14.0  diary products and alternatives
# 17                       14.0                           others
# 18                       14.0            vegetables and fruits
# 19                       14.0                         proteins
# 20                       14.0            vegetables and fruits
# 21                       14.0        sugar sweets and bakeries
# 22                       14.0                           others
# 23                       14.0            vegetables and fruits
# 24                       14.0            vegetables and fruits
# 25                       14.0                           others
# 26                       14.0                           others
# 27                       14.0            vegetables and fruits
# 28                       14.0                           others
# 29                       26.0            vegetables and fruits
# ...                       ...                              ...
# 22276                    30.0        sugar sweets and bakeries
# 22277                    30.0                           others
# 22278                    30.0                  processed foods
# 22279                    30.0                           others
# 22280                    30.0                           others
# 22281                    30.0                           others
# 22282                     6.0        sugar sweets and bakeries
# 22283                     9.0                           others
# 22284                     9.0            vegetables and fruits
# 22285                     9.0            vegetables and fruits
# 22286                     9.0            vegetables and fruits
# 22287                    30.0                           others
# 22288                    30.0            vegetables and fruits
# 22289                    30.0                           others
# 22290                    21.0                           others
# 22291                    21.0            vegetables and fruits
# 22292                    12.0            vegetables and fruits
# 22293                    12.0                           others
# 22294                    12.0                           others
# 22295                    30.0                    carbohydrates
# 22296                    30.0                           others
# 22297                    30.0                           others
# 22298                    30.0                           others
# 22299                    30.0            vegetables and fruits
# 22300                    30.0            vegetables and fruits
# 22301                    30.0  diary products and alternatives
# 22302                    15.0                           others
# 22303                    15.0                           others
# 22304                     7.0                  processed foods
# 22305                     7.0            vegetables and fruits
#
# [22306 rows x 17 columns]
