# %%
#import basic Libraries
import pandas as pd
import numpy as np
import random

#Importing Sklearn
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics.pairwise import cosine_similarity

import warnings
warnings.filterwarnings("ignore")

# %%
opt = pd.read_csv('../data/merged_data_for_diet.csv')
opt = opt.drop('Unnamed: 0', axis=1)
opt.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  \
# 0         1       11109                  2          1
# 1         1       22035                  8          1
# 2        36       19660                  2          1
# 3        36       48679                  7          1
# 4        36       46979                  8          1
#
#                                     product_name  aisle_id  department_id  \
# 0  Organic 4% Milk Fat Whole Milk Cottage Cheese       108             16
# 1                    Organic Whole String Cheese        21             16
# 2                                   Spring Water       115              7
# 3              Organic Garnet Sweet Potato (Yam)        83              4
# 4                                      Asparagus        83              4
#
#    department                          aisle  hi_dem  user_id eval_set  \
# 0  dairy eggs           other creams cheeses    True   112108    train
# ...

# %%
#return the total items in the basket from the aisles
user_diet = opt.groupby(['foodgroup','user_id']).size().sort_values(ascending=False).unstack().fillna(0)

# %%
user_diet.loc[:,]
# Out:
# foodgroup
# carbohydrates                      0.0
# diary products and alternatives    0.0
# fat                                0.0
# others                             1.0
# processed foods                    1.0
# proteins                           0.0
# sugar sweets and bakeries          0.0
# vegetables and fruits              1.0
# Name: 55, dtype: float64

# %%
list_user_id = user_diet.columns

# %%
for uid in list_user_id:›
    print(user_diet.loc[:, uid])
# Out:
# foodgroup
# carbohydrates                      0.0
# diary products and alternatives    0.0
# fat                                0.0
# others                             1.0
# processed foods                    1.0
# proteins                           0.0
# sugar sweets and bakeries          0.0
# vegetables and fruits              1.0
# Name: 55, dtype: float64
# foodgroup
# carbohydrates                      0.0
# diary products and alternatives    0.0
# fat                                0.0
# others                             0.0
# processed foods                    1.0
# proteins                           0.0
# sugar sweets and bakeries          0.0
# vegetables and fruits              3.0
# Name: 56, dtype: float64
# foodgroup
# carbohydrates                      0.0
# diary products and alternatives    0.0
# fat                                0.0
# others                             0.0
# processed foods                    0.0
# proteins                           0.0
# ...
